# %% [markdown]
# # Data cleaning

# %%
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt 

df1 = pd.read_csv('steps-1.csv',delimiter = ";")
df1['Mean steps per participant']= df1.mean(axis=1)
df1.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  5-5-2014  6-5-2014  7-5-2014  \
# 0     9929.0    12879.0    10541.0  ...       NaN       NaN       NaN
# 1     4024.0     3926.0    14595.0  ...       NaN       NaN       NaN
# 2     8185.0     9630.0     8983.0  ...    4364.0       NaN       NaN
# 3        NaN        NaN        NaN  ...       NaN       NaN       NaN
# 4        NaN        NaN        NaN  ...       NaN       NaN       NaN
#
#    8-5-2014  9-5-2014  10-5-2014  11-5-2014  12-5-2014  13-5-2014  \
# ...

# %%
df2 = pd.read_csv('survey.csv')
df2['weight'].replace({700:0}, inplace=True)
df2 = df2.dropna()
df2.head()
# Out:
#    id         city  gender    age  hh_size  education          education_1  \
# 0   1     Bordeaux    Male  25-34        4          4  Master or doctorate
# 1   2        Lille    Male  35-44        1          3             Bachelor
# 2   3  Montpellier    Male  25-34        2          2  Master or doctorate
# 3   4         Lyon    Male    <25        1          1             Bachelor
# 4   5  Montpellier  Female  25-34        3          4             Bachelor
#
#    height  weight
# 0   178.0    98.0
# 1   180.0    77.0
# 2   180.0    83.0
# 3   178.0    80.0
# 4   167.0    61.0

# %%
df2.describe()
# Out:
#                id     hh_size   education      height      weight
# count  926.000000  926.000000  926.000000  926.000000  926.000000
# mean   464.316415    2.344492    2.532397  171.677106   72.099352
# std    267.963750    1.226336    1.273653    9.081282   15.849797
# min      1.000000    1.000000    1.000000  145.000000    0.000000
# 25%    232.250000    1.000000    1.250000  165.000000   61.000000
# 50%    464.500000    2.000000    2.000000  172.000000   71.000000
# 75%    695.750000    3.000000    4.000000  179.000000   81.000000
# max    929.000000   11.000000    5.000000  195.000000  155.000000

# %%
df = pd.merge(df1, df2, on = 'id')
df.head()
# Out:
#    id  20-6-2013  21-6-2013  22-6-2013  23-6-2013  24-6-2013  25-6-2013  \
# 0   1        NaN        NaN        NaN        NaN     3941.0    15733.0
# 1   2        NaN        NaN    10473.0      705.0     4287.0     5507.0
# 2   3        NaN    11428.0    12523.0     2553.0      190.0     2164.0
# 3   4        NaN        NaN        NaN        NaN        NaN        NaN
# 4   5        NaN        NaN        NaN        NaN        NaN        NaN
#
#    26-6-2013  27-6-2013  28-6-2013  ...  13-5-2014  \
# 0     9929.0    12879.0    10541.0  ...        NaN
# 1     4024.0     3926.0    14595.0  ...        NaN
# 2     8185.0     9630.0     8983.0  ...        NaN
# 3        NaN        NaN        NaN  ...        NaN
# 4        NaN        NaN        NaN  ...        NaN
#
#    Mean steps per participant         city  gender    age  hh_size  education  \
# 0                10144.048193     Bordeaux    Male  25-34        4          4
# ...

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# ### Graph of the distribution
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt

# %%
df['Mean steps per participant'].name = 'Mean steps per participant'
Mean_steps = df['Mean steps per participant'].dropna()
sns.distplot(Mean_steps, kde=False) 
plt.title('Histogram of mean steps per participant')
plt.show()
# Out:
# C:\Users\huhon\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mean_steps = df['Mean steps per participant'].mean()
median_steps = df['Mean steps per participant'].median()

print(f'The median filesize is: {median_steps}')
print(f'The median filesize is: {mean_steps}')

sns.distplot(Mean_steps, kde=False)
plt.title('Histogram of mean steps per participant')
plt.axvline(median_steps, 0, 100, color='green', label='median') 
plt.axvline(mean_steps, 0, 100, color='red', label='mean') 
plt.legend()
plt.show()
# Out:
# The median filesize is: 6081.921944444444
# The median filesize is: 6812.4496442886775

# %% [markdown]
# ###  The relation of mean steps per participant with a categorical variable with two levels

# %%
sns.set_theme(style="whitegrid")
gender = df["gender"]
sns.violinplot(x= df["gender"] ,y= df['Mean steps per participant'],hue=df["gender"],
                     palette="muted", split=True)

plt.title('Gender and mean steps per participant')
plt.ylabel('Gender')
plt.xlabel('Mean steps per participant')

plt.show()

# %% [raw]
# This Boxplot illustrates the relationship between the age of participants and thier mean steps.

# %%
sns.set(style="darkgrid")
df["age"] = sorted(df["age"])
sns.boxplot( x=df["Mean steps per participant"], y=df["age"],width=0.5)
plt.show()

# %% [markdown]
# ### The relation between two categorical variables

# %% [raw]
# This Barplot illustrates the relationship between participants' ages and thier mean steps.

# %%
sns.set(style= "darkgrid")
sns.barplot(x=df["age"], y=df["Mean steps per participant"], hue=df["age"],linewidth=0.01)
plt.show()

# %% [raw]
# This Hexbin plot with marginal distributions shows the relationship between weight an the mean steps of per participant.

# %%
sns.jointplot(x=df["weight"], y=df["Mean steps per participant"], kind="hex", color="#4CB391")
plt.show()
